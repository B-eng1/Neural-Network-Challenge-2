# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
X_columns = ['Age', 'Education', 'PercentSalaryHike', 'EducationField', 'JobInvolvement','WorkLifeBalance', 'NumCompaniesWorked', 'StockOptionLevel', 'HourlyRate', 'YearsAtCompany']




# Create X_df using your selected columns
x_df = attrition_df[X_columns]

# Show the data types for X_df
x_df.head()
# Out:
#    Age  Education  PercentSalaryHike EducationField  JobInvolvement  \
# 0   41          2                 11  Life Sciences               3
# 1   49          1                 23  Life Sciences               2
# 2   37          2                 15          Other               2
# 3   33          4                 11  Life Sciences               3
# 4   27          1                 12        Medical               3
#
#    WorkLifeBalance  NumCompaniesWorked  StockOptionLevel  HourlyRate  \
# 0                1                   8                 0          94
# 1                3                   1                 1          61
# 2                3                   6                 0          92
# 3                3                   1                 0          56
# 4                3                   9                 1          40
#
#    YearsAtCompany
# 0               6
# 1              10
# 2               0
# 3               8
# 4               2

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, random_state=78)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
X_train.head()
# Out:
#       Age  Education  PercentSalaryHike  JobInvolvement  WorkLifeBalance  \
# 591    33          3                 15               3                3
# 267    25          2                 12               4                3
# 1236   36          5                 13               2                3
# 788    28          3                 13               3                4
# 1224   26          4                 15               1                4
#
#       NumCompaniesWorked  StockOptionLevel  HourlyRate  YearsAtCompany  \
# 591                    5                 0          69               3
# 267                    1                 2          85               6
# 1236                   5                 3          96               2
# 788                    3                 0          59               8
# 1224                   1                 3          62               3
#
#       EducationField_Human Resources  EducationField_Life Sciences  \
# ...

# %%
# Create a StandardScaler
from sklearn.preprocessing import StandardScaler
X_Scaler = StandardScaler()
# Fit the StandardScaler to the training data
X_Scaler.fit(X_train)

# Scale the training and testing data
X_train_Scaled = X_Scaler.transform(X_train)
X_test_Scaled = X_Scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder


# Create a OneHotEncoder for the Department column
encoder = OneHotEncoder(sparse_output=True)
encoded_departments = encoder.fit_transform(y_train[['Department']])

# Fit the encoder to the training data
encoder.fit(y_train[['Department']])


# Create two new variables by applying the encoder
# to the training and testing data
y_train_encoded = pd.DataFrame(encoder.transform(y_train[['Department']]))
y_test_encoded = pd.DataFrame(encoder.transform(y_test[['Department']]))

# %%
# Create a OneHotEncoder for the Attrition column
encoder = OneHotEncoder(sparse_output=True)
encoded  = encoder.fit_transform(y_train[['Attrition']])

# Fit the encoder to the training data
encoder.fit(y_train[['Attrition']])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_department = pd.DataFrame(encoder.transform(y_train[['Attrition']]))
y_test_department = pd.DataFrame(encoder.transform(y_test[['Attrition']]))

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
X_columns = X_train.shape[1]


# Create the input layer
input_layer_1 = layers.Input(shape=(X_columns,))
input_layer_2 = layers.Input(shape=(3,))
num_rows = X_train.shape[0]
num_rows = X_train.shape[1]

# Create at least two shared layers
shared_layer1 = layers.Dense(units=10, activation='relu')(input_layer_1)
shared_layer2 = layers.Dense(units=10, activation='relu')(shared_layer1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer
from tensorflow.keras.models import Model
from tensorflow.keras import layers

input_layer_1 = layers.Input(shape=(X_columns,))
shared_dense = layers.Dense(units=10, activation='relu')
department_input_ = layers.Input(shape=(3,))
x1 = shared_dense(department_input_)
x1 = layers.Dense(32, activation='relu')(x1)
output_1 = layers.Dense(2, activation='sigmoid')(x1)
# Create the hidden layer
hidden_layer1 = layers.Dense(units=10, activation='relu')(input_layer_1)

# Create the output layer
output_layer1 = layers.Dense(units=2, activation='sigmoid')(hidden_layer1)

# Create the model
model = Model(inputs=[input_layer_1, department_input_],outputs=[output_layer1, output_1])

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer
hidden_layer1= layers.Dense(units=10, activation='relu')(input_layer_1)
output_layer1 = layers.Dense(units=2, activation='sigmoid')(hidden_layer1)
# Create the hidden layer
hidden_layer2 = layers.Dense(units=10, activation='relu')(input_layer_2)

# Create the output layer
output_layer2 = layers.Dense(units=2, activation='sigmoid')(hidden_layer2)

# %%
# Create the model
model = Model(inputs=[input_layer_1, input_layer_2], outputs=[output_layer1, output_layer2])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Summarize the model
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 15)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 3)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
# Train the model
y_train['Attrition'] = y_train['Attrition'].map({'Yes': 1, 'No': 0})
y_train_encoded = pd.get_dummies(y_train, columns=['Attrition', 'Department']).astype(np.float32)

y_train_department_encoded = pd.get_dummies(y_train, columns=['Department']).values.astype(np.float32)
model.fit([X_train_Scaled, y_train_department_encoded], [attrition_target, department_target], epochs=10, batch_size=32, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-0ca227b4077c> in <cell line: 0>()
#       3 y_train_encoded = pd.get_dummies(y_train, columns=['Attrition', 'Department']).values.astype(np.float32)
#       4 y_train_department_encoded = pd.get_dummies(y_train, columns=['Department']).values.astype(np.float32)
# ----> 5 model.fit([X_train_Scaled, y_train_department_encoded], [attrition_target, department_target], epochs=10, batch_size=32, validation_split=0.2)
#       6
#       7
#
# NameError: name 'attrition_target' is not defined

# %%
# Evaluate the model with the testing data
y_test['Attrition'] = y_test['Attrition'].map({'Yes': 1, 'No': 0})
y_test_encoded = y_test['Attrition'].to_numpy().astype(np.float32)

# %%
# Print the accuracy for both department and attrition
print(f"Department Accuracy: {department_accuracy}")
print(f"Attrition Accuracy: {attrition_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-063db9d22db0> in <cell line: 0>()
#       1 # Print the accuracy for both department and attrition
# ----> 2 print(f"Department Accuracy: {department_accuracy}")
#       3 print(f"Attrition Accuracy: {attrition_accuracy}")
#
# NameError: name 'department_accuracy' is not defined

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1.
# 2.
# 3.
